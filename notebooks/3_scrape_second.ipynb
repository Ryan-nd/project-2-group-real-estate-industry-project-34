# %%
import requests
import json
import time

# Client credentials
client_id = 'client_4be73be280ece81767f386e50b2bb7e5'
client_secret = 'secret_3c5eff9a791bd41eeb16feada4a1131b'
scopes = ['api_listings_read']

# Authentication URL
auth_url = 'https://auth.domain.com.au/v1/connect/token'

# List of agency IDs
# agency_ids = ["19", "2795", "11154", "4478", "7307", "4475", "3724", "20823"]

agency_ids = ["31835", "28477", "19574", "3723", "15529", "35358", "4850", "31519", "30252"]

# Parameters for the GET request
params = {
    'listingStatusFilter': 'liveAndArchived',
    'pageSize': 200  # Fetching 200 listings per page
}

def get_access_token():
    response = requests.post(auth_url, data={
        'client_id': client_id,
        'client_secret': client_secret,
        'grant_type': 'client_credentials',
        'scope': ' '.join(scopes),
        'Content-Type': 'application/x-www-form-urlencoded'
    })
    
    json_response = response.json()
    return json_response['access_token']

def fetch_agency_data(agency_id, access_token):
    headers = {"Authorization": f"Bearer {access_token}"}
    all_listings = []
    
    # Iterate through pages 100 to 200
    for page_number in range(1, 300):
        params['pageNumber'] = page_number
        url_endpoint = f'https://api.domain.com.au/sandbox/v1/agencies/{agency_id}/listings'

        response = requests.get(url_endpoint, headers=headers, params=params)
        
        if response.status_code == 200:
            listings = response.json()
            if not listings:  # If no listings, stop fetching further pages
                print(f"No more listings found at page {page_number} for agency {agency_id}.")
                break
            all_listings.extend(listings)
            print(f"Fetched {len(listings)} listings from page {page_number} for agency {agency_id}.")
        else:
            print(f"Failed to retrieve data for agency {agency_id} on page {page_number}: {response.status_code} - {response.reason}")
            break  # Stop if page doesn't exist or there's another error

        # Optional: Sleep between requests to avoid rate limiting
        time.sleep(1)
    
    return all_listings

def main():
    access_token = get_access_token()
    
    for agency_id in agency_ids:
        print(f"Fetching data for agency {agency_id}...")
        listings = fetch_agency_data(agency_id, access_token)
        
        # Store the data (e.g., save to a JSON file)
        with open(f'../data/landing/listings_agency_{agency_id}.json', 'w') as f:
            json.dump(listings, f, indent=2)
        
        print(f"Data for agency {agency_id} saved.\n")

if __name__ == "__main__":
    main()
# Out:
# Fetching data for agency 31835...
# Fetched 200 listings from page 1 for agency 31835.
# Fetched 144 listings from page 2 for agency 31835.
# No more listings found at page 3 for agency 31835.
# Data for agency 31835 saved.
#
# Fetching data for agency 28477...
# Fetched 200 listings from page 1 for agency 28477.
# Fetched 200 listings from page 2 for agency 28477.
# Fetched 200 listings from page 3 for agency 28477.
# Fetched 75 listings from page 4 for agency 28477.
# No more listings found at page 5 for agency 28477.
# Data for agency 28477 saved.
#
# Fetching data for agency 19574...
# Fetched 200 listings from page 1 for agency 19574.
# Fetched 200 listings from page 2 for agency 19574.
# Fetched 200 listings from page 3 for agency 19574.
# Fetched 200 listings from page 4 for agency 19574.
# Fetched 200 listings from page 5 for agency 19574.
# Fetched 200 listings from page 6 for agency 19574.
# Fetched 200 listings from page 7 for agency 19574.
# Fetched 200 listings from page 8 for agency 19574.
# Fetched 200 listings from page 9 for agency 19574.
# Fetched 200 listings from page 10 for agency 19574.
# Fetched 200 listings from page 11 for agency 19574.
# Fetched 200 listings from page 12 for agency 19574.
# Fetched 200 listings from page 13 for agency 19574.
# Fetched 200 listings from page 14 for agency 19574.
# Fetched 200 listings from page 15 for agency 19574.
# Fetched 200 listings from page 16 for agency 19574.
# Fetched 200 listings from page 17 for agency 19574.
# Fetched 200 listings from page 18 for agency 19574.
# Fetched 7 listings from page 19 for agency 19574.
# No more listings found at page 20 for agency 19574.
# Data for agency 19574 saved.
#
# Fetching data for agency 3723...
# Fetched 200 listings from page 1 for agency 3723.
# Fetched 200 listings from page 2 for agency 3723.
# Fetched 200 listings from page 3 for agency 3723.
# Fetched 200 listings from page 4 for agency 3723.
# Fetched 200 listings from page 5 for agency 3723.
# Fetched 200 listings from page 6 for agency 3723.
# Fetched 200 listings from page 7 for agency 3723.
# Fetched 200 listings from page 8 for agency 3723.
# Fetched 200 listings from page 9 for agency 3723.
# Fetched 200 listings from page 10 for agency 3723.
# Fetched 200 listings from page 11 for agency 3723.
# Fetched 200 listings from page 12 for agency 3723.
# Fetched 200 listings from page 13 for agency 3723.
# Fetched 200 listings from page 14 for agency 3723.
# Fetched 200 listings from page 15 for agency 3723.
# Fetched 200 listings from page 16 for agency 3723.
# Fetched 200 listings from page 17 for agency 3723.
# Fetched 200 listings from page 18 for agency 3723.
# Fetched 200 listings from page 19 for agency 3723.
# Fetched 200 listings from page 20 for agency 3723.
# Fetched 200 listings from page 21 for agency 3723.
# Fetched 200 listings from page 22 for agency 3723.
# Fetched 200 listings from page 23 for agency 3723.
# Fetched 200 listings from page 24 for agency 3723.
# Fetched 200 listings from page 25 for agency 3723.
# Fetched 200 listings from page 26 for agency 3723.
# Fetched 200 listings from page 27 for agency 3723.
# Fetched 200 listings from page 28 for agency 3723.
# Fetched 200 listings from page 29 for agency 3723.
# Fetched 200 listings from page 30 for agency 3723.
# Fetched 200 listings from page 31 for agency 3723.
# Fetched 200 listings from page 32 for agency 3723.
# Fetched 200 listings from page 33 for agency 3723.
# Fetched 200 listings from page 34 for agency 3723.
# Fetched 65 listings from page 35 for agency 3723.
# No more listings found at page 36 for agency 3723.
# Data for agency 3723 saved.
#
# Fetching data for agency 15529...
# Fetched 200 listings from page 1 for agency 15529.
# Fetched 200 listings from page 2 for agency 15529.
# Fetched 200 listings from page 3 for agency 15529.
# Fetched 200 listings from page 4 for agency 15529.
# Fetched 200 listings from page 5 for agency 15529.
# Fetched 200 listings from page 6 for agency 15529.
# Fetched 155 listings from page 7 for agency 15529.
# No more listings found at page 8 for agency 15529.
# Data for agency 15529 saved.
#
# Fetching data for agency 35358...
# Fetched 200 listings from page 1 for agency 35358.
# Fetched 200 listings from page 2 for agency 35358.
# Fetched 200 listings from page 3 for agency 35358.
# Fetched 200 listings from page 4 for agency 35358.
# Fetched 200 listings from page 5 for agency 35358.
# Fetched 200 listings from page 6 for agency 35358.
# Fetched 200 listings from page 7 for agency 35358.
# Fetched 200 listings from page 8 for agency 35358.
# Fetched 158 listings from page 9 for agency 35358.
# No more listings found at page 10 for agency 35358.
# Data for agency 35358 saved.
#
# Fetching data for agency 4850...
# Fetched 200 listings from page 1 for agency 4850.
# Fetched 200 listings from page 2 for agency 4850.
# Fetched 200 listings from page 3 for agency 4850.
# Fetched 200 listings from page 4 for agency 4850.
# Fetched 200 listings from page 5 for agency 4850.
# Fetched 200 listings from page 6 for agency 4850.
# Fetched 200 listings from page 7 for agency 4850.
# Fetched 200 listings from page 8 for agency 4850.
# Fetched 200 listings from page 9 for agency 4850.
# Fetched 200 listings from page 10 for agency 4850.
# Fetched 200 listings from page 11 for agency 4850.
# Fetched 200 listings from page 12 for agency 4850.
# Fetched 200 listings from page 13 for agency 4850.
# Fetched 200 listings from page 14 for agency 4850.
# Fetched 200 listings from page 15 for agency 4850.
# Fetched 200 listings from page 16 for agency 4850.
# Fetched 200 listings from page 17 for agency 4850.
# Fetched 200 listings from page 18 for agency 4850.
# Fetched 200 listings from page 19 for agency 4850.
# Fetched 200 listings from page 20 for agency 4850.
# Fetched 200 listings from page 21 for agency 4850.
# Fetched 200 listings from page 22 for agency 4850.
# Fetched 200 listings from page 23 for agency 4850.
# Fetched 200 listings from page 24 for agency 4850.
# Fetched 200 listings from page 25 for agency 4850.
# Fetched 200 listings from page 26 for agency 4850.
# Fetched 200 listings from page 27 for agency 4850.
# Fetched 200 listings from page 28 for agency 4850.
# Fetched 200 listings from page 29 for agency 4850.
# Fetched 200 listings from page 30 for agency 4850.
# Fetched 200 listings from page 31 for agency 4850.
# Fetched 66 listings from page 32 for agency 4850.
# No more listings found at page 33 for agency 4850.
# Data for agency 4850 saved.
#
# Fetching data for agency 31519...
# Fetched 200 listings from page 1 for agency 31519.
# Fetched 200 listings from page 2 for agency 31519.
# Fetched 200 listings from page 3 for agency 31519.
# Fetched 200 listings from page 4 for agency 31519.
# Fetched 200 listings from page 5 for agency 31519.
# Fetched 200 listings from page 6 for agency 31519.
# Fetched 200 listings from page 7 for agency 31519.
# Fetched 27 listings from page 8 for agency 31519.
# No more listings found at page 9 for agency 31519.
# Data for agency 31519 saved.
#
# Fetching data for agency 30252...
# Fetched 200 listings from page 1 for agency 30252.
# Fetched 200 listings from page 2 for agency 30252.
# Fetched 200 listings from page 3 for agency 30252.
# Fetched 200 listings from page 4 for agency 30252.
# Fetched 200 listings from page 5 for agency 30252.
# Fetched 17 listings from page 6 for agency 30252.
# No more listings found at page 7 for agency 30252.
# Data for agency 30252 saved.

# %%
import os
import requests
import json
import time

# Client credentials
client_id = 'client_4be73be280ece81767f386e50b2bb7e5'
client_secret = 'secret_3c5eff9a791bd41eeb16feada4a1131b'
scopes = ['api_listings_read']

# Authentication URL
auth_url = 'https://auth.domain.com.au/v1/connect/token'

# Directory where the files are stored
json_dir = '../data/landing/'

# List of agency IDs to scrape (new agencies)
agency_ids = ["5808", "20095", "15964", "20419", "35720"]
#["5005", "14522", "18039", "11825", "6500", "33982", "20864", "11919", "7301", "14503", "32621", "20366", "12612", "35120", "31119", "26113", "21762", "12438", "1638", "11673", "16668", "26896", "26155", "4740", "19325", "32238", "6936", "13411", "25876", "31452", "5808", "10292", "31040", "17234", "11765", "33394", "22721", "7636", "11862", "4714", "19113", "7218", "21537", "32633", "36194", "23154"]
#["32569", "22013", "32851", "30107", "27962", "7728", "20095", "18765", "17337", "15964", "34590", "20419", "4719", "32474", "24322", "3709", "22748", "35557", "32563", "15424", "29733", "22398", "35720", ]

# Parameters for the GET request
params = {
    'listingStatusFilter': 'liveAndArchived',
    'pageSize': 200  # Fetching 200 listings per page
}

def get_access_token():
    response = requests.post(auth_url, data={
        'client_id': client_id,
        'client_secret': client_secret,
        'grant_type': 'client_credentials',
        'scope': ' '.join(scopes),
        'Content-Type': 'application/x-www-form-urlencoded'
    })
    
    json_response = response.json()
    return json_response['access_token']

def fetch_agency_data(agency_id, access_token):
    headers = {"Authorization": f"Bearer {access_token}"}
    all_listings = []
    
    # Iterate through pages 1 to 300
    for page_number in range(1, 300):
        params['pageNumber'] = page_number
        url_endpoint = f'https://api.domain.com.au/sandbox/v1/agencies/{agency_id}/listings'

        response = requests.get(url_endpoint, headers=headers, params=params)
        
        if response.status_code == 200:
            listings = response.json()
            if not listings:  # If no listings, stop fetching further pages
                print(f"No more listings found at page {page_number} for agency {agency_id}.")
                break
            all_listings.extend(listings)
            print(f"Fetched {len(listings)} listings from page {page_number} for agency {agency_id}.")
        else:
            print(f"Failed to retrieve data for agency {agency_id} on page {page_number}: {response.status_code} - {response.reason}")
            break  # Stop if there's another error

        # Optional: Sleep between requests to avoid rate limiting
        time.sleep(1)
    
    return all_listings

def get_existing_agency_ids(directory):
    """Get a list of agency IDs from the existing JSON files in the directory."""
    existing_files = [f for f in os.listdir(directory) if f.startswith('listings_agency_') and f.endswith('.json')]
    existing_agency_ids = set()

    for file in existing_files:
        try:
            # Extract agency ID, assumes filenames are like: 'listings_agency_<agency_id>_agency_name.json'
            agency_id = file.split('_')[2]
            existing_agency_ids.add(agency_id)
        except IndexError:
            # Handle unexpected file names
            print(f"Could not extract agency ID from {file}")
    
    return existing_agency_ids

def main():
    access_token = get_access_token()
    
    # Get the set of existing agency IDs
    existing_agency_ids = get_existing_agency_ids(json_dir)

    # Filter out agency IDs that already have a file
    new_agency_ids = [agency_id for agency_id in agency_ids if agency_id not in existing_agency_ids]
    
    if not new_agency_ids:
        print("All agencies have already been scraped.")
        return

    for agency_id in new_agency_ids:
        print(f"Fetching data for agency {agency_id}...")
        listings = fetch_agency_data(agency_id, access_token)
        
        # Store the data (e.g., save to a JSON file)
        with open(f'{json_dir}new/listings_agency_{agency_id}.json', 'w') as f:
            json.dump(listings, f, indent=2)
        
        print(f"Data for agency {agency_id} saved.\n")

if __name__ == "__main__":
    main()
# Out:
# Fetching data for agency 5808...
# Failed to retrieve data for agency 5808 on page 1: 207 - Multi-Status
# Data for agency 5808 saved.
#
# Fetching data for agency 20095...
# Failed to retrieve data for agency 20095 on page 1: 207 - Multi-Status
# Data for agency 20095 saved.
#
# Fetching data for agency 15964...
# Failed to retrieve data for agency 15964 on page 1: 207 - Multi-Status
# Data for agency 15964 saved.
#
# Fetching data for agency 20419...
# Failed to retrieve data for agency 20419 on page 1: 207 - Multi-Status
# Data for agency 20419 saved.
#
# Fetching data for agency 4719...
# Failed to retrieve data for agency 4719 on page 1: 207 - Multi-Status
# Data for agency 4719 saved.
#
# Fetching data for agency 3709...
# Failed to retrieve data for agency 3709 on page 1: 207 - Multi-Status
# Data for agency 3709 saved.
#
# Fetching data for agency 35720...
# Failed to retrieve data for agency 35720 on page 1: 207 - Multi-Status
# Data for agency 35720 saved.
